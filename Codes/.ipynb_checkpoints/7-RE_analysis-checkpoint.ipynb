# %% [markdown]
# # Analysis of the RE scores to generate predictions

# %% [markdown]
# ## Imports, functions and definitions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm
from scipy.stats import genextreme
from sklearn.mixture import GaussianMixture

# %%
pwd
# Out:
# '/Users/rtaujale/Dropbox (Edison_Lab@UGA)/Projects/GT_informatics/GT/GT_strML/Github_Folder/GT-CNN/Codes'

# %%
def calcSubScore(row):
    allval=list()
    for i in range(1,10):
        cname=row.index[i]
        val=float(row[i])
        sc=float(re_values['SC'][cname])
        ooc=float(re_values['OOC'][cname])
        oof=float(re_values['OOF'][cname])
#         score=(ooc-val)/(val-sc)#/oof#/(oof-sc)
        score=((ooc-val)/(oof-sc))-0.08
        
        allval.append(score)
    return(pd.Series(allval))

def Plot_Dist_Extreme(r_err, GT_val, interval = 0.99):
    covMat = np.array(r_err["Err"], dtype=float)
    median = np.median(covMat)
    c, loc, scale = genextreme.fit(covMat, floc=median)
    min_extreme,max_extreme = genextreme.interval(interval,c,loc,scale)
    x = np.linspace(min(covMat),max(covMat),2000)
    fig,ax = plt.subplots(1, 1)
    plt.xlim(0,1)
    plt.plot(x, genextreme.pdf(x, *genextreme.fit(covMat)))
    plt.hist(np.array(r_err["Err"], dtype=float),bins=100,alpha=0.7, density=True)
    plt.hist(np.asarray(GT_val["Err"]), edgecolor='k', alpha=0.35, bins=1000, density=True)
    plt.xlabel('Lengths Counts')
    plt.ylabel('Probability')
    plt.title(r'min_extreme=%.3f,max_extreme=%.3f' %(min_extreme, max_extreme))
    plt.annotate('Max Extreme Value',xy=(max_extreme,0),xytext=(max_extreme,1),arrowprops=dict(arrowstyle="->",connectionstyle="arc3",color="black"),color="black")
    plt.grid(True)
    return c, loc, scale

def Plot_Dist_Train_Extreme(r_err, GT_val,bin1=500,bin2=500,interval1 = 0.95,interval2=0.99):
    covMat = np.array(r_err["Err"], dtype=float)
    median = np.median(covMat)
    c, loc, scale = genextreme.fit(covMat, floc=median)
    min_extreme1,max_extreme1 = genextreme.interval(interval1,c,loc,scale)
    min_extreme2,max_extreme2 = genextreme.interval(interval2,c,loc,scale)
    x = np.linspace(min(covMat),max(covMat),2000)
    fig,ax = plt.subplots(figsize = (30,10))
    plt.xlim(0,0.4)
    plt.plot(x, genextreme.pdf(x, *genextreme.fit(covMat)), linewidth=5)
    plt.hist(np.array(r_err["Err"], dtype=float),bins=bin1,alpha=0.3,density=True,edgecolor='black',facecolor='gray', linewidth=3,histtype='stepfilled') #{'bar', 'barstacked', 'step', 'stepfilled'})
    plt.hist(np.asarray(GT_val["Err"]), bins=bin2, alpha=0.3,density=True,edgecolor='red',facecolor='red', linewidth=3,histtype='stepfilled')
    plt.xlabel('Lengths Counts')
    plt.ylabel('Probability')
    plt.title(r'max_extreme1=%.3f,max_extreme2=%.3f' %(max_extreme1, max_extreme2))
    ax.tick_params(left = False, bottom = False)
    
    ax.axvline(min_extreme1, alpha = 0.9, ymax = 0.20, linestyle = ":",linewidth=3,color="red") #,
    ax.axvline(max_extreme1, alpha = 0.9, ymax = 0.20, linestyle = ":",linewidth=3,color="red") #,
    ax.text(min_extreme1, 8, "5th", size = 20, alpha = 0.8,color="red")
    ax.text(max_extreme1, 8, "95th", size = 20, alpha =.8,color="red")
    ax.axvline(min_extreme2, alpha = 0.9, ymax = 0.20, linestyle = ":",linewidth=3,color="red") #,
    ax.axvline(max_extreme2, alpha = 0.9, ymax = 0.20, linestyle = ":",linewidth=3,color="red") #,
    ax.text(min_extreme2, 8, "1st", size = 20, alpha = 0.8,color="red")
    ax.text(max_extreme2, 8, "99th", size = 20, alpha =.8,color="red")
    
    print("95% CI upper bound:",max_extreme1)
    print("99% CI upper bound:",max_extreme2)
    print("Median RE:",np.median(np.array(GT_val["Err"], dtype=float)))
    
    return c, loc, scale, fig,ax

def Plot_Dist_SubClust_Extreme(r_err, GT_val,bin1=100,bin2=50):
    covMat = np.array(r_err["Err"], dtype=float)
    median = np.median(covMat)
    x = np.linspace(min(covMat),max(covMat),2000)
    fig,ax = plt.subplots(figsize = (30,10))
    plt.xlim(0,1)
    plt.hist(np.array(r_err["Err"], dtype=float),bins=bin1,alpha=0.3,density=True,edgecolor='black',facecolor='gray', linewidth=3,histtype='stepfilled') #{'bar', 'barstacked', 'step', 'stepfilled'})
    plt.hist(np.asarray(GT_val["Err"]), bins=bin2, alpha=0.3,density=True,edgecolor='darkred',facecolor='red', linewidth=3,histtype='stepfilled')
    plt.xlabel('Lengths Counts')
    plt.ylabel('Probability')
    ax.tick_params(left = False, bottom = False) 
    return fig,ax

def histogram(x, **kwargs):
    y, x = np.histogram(x, **kwargs)
    x, y = (x[1:]+x[:-1])/2, y
    return x, y

def Integral(X1, X2,bin1=300,bin2=300,figure=True):
    kwargs1  = {'bins':bin1, 'range':[0,3]}
    kwargs2  = {'bins':bin2, 'range':[0,3]}
    
    x1, y1  = histogram(X1['Err'].values, **kwargs1)
    y1 = [float(i)/sum(y1) for i in y1]
    x2, y2  = histogram(X2['Err'].values, **kwargs2)
    y2 = [float(i)/sum(y2) for i in y2]
    overlap = np.array(list(map(min, zip(y1, y2))))
    if (figure):
        plt.figure(figsize=(15,5))
        plt.plot(x1,y1)    
        plt.plot(x2,y2)    
        if len(x1)==len(overlap):
            plt.plot(x1,overlap)    
        print(overlap.sum())
   
    return overlap.sum()

# %%
allgtfam=["GT1-B","GT2-A","GT3-B","GT4-B","GT5-B","GT6-A","GT7-A","GT8-A","GT9-B","GT10-B","GT11-u","GT12-A","GT13-A","GT14-A","GT15-A","GT16-A","GT17-A","GT18-B","GT19-B","GT20-B","GT21-A","GT22-C","GT23-B","GT24-A","GT25-A","GT26-u","GT27-A","GT28-B","GT29-u","GT30-B","GT31-A","GT32-A","GT33-B","GT34-A","GT35-B","GT37-B","GT38-B","GT39-C","GT40-A","GT41-B","GT42-u","GT43-A","GT44-u","GT45-A","GT47-B","GT48-u","GT49-A","GT50-C","GT51-lyso","GT52-B","GT53-u","GT54-A","GT55-A","GT56-B","GT57-C","GT58-C","GT59-C","GT60-A","GT61-B","GT62-A","GT63-B","GT64-A","GT65-B","GT66-C","GT67-A","GT68-B","GT69-u","GT70-B","GT71-u","
# gta1=["GT15-A","GT17-A","GT31-A","GT43-A","GT7-A","GT77-A"]
gtb0 = ["GT1-B","GT10-B","GT20-B","GT28-B","GT37-B","GT38-B","GT4-B","GT5-B","GT63-B","GT72-B","GT79-B","GT9-B","GT90-B","GT93-B"]
# gtb1 = ["GT3-B","GT35-B","GT41-B"]
gtb1 = ["GT3-B","GT18-B","GT19-B","GT23-B","GT35-B"]
gtb2 = ["GT104-B","GT30-B","GT70-B"]
gtc0 = ["GT39-C","GT57-C","GT66-C"]
gtc1 = ["GT50-C","GT58-C","GT87-C"]
gtc2 = ["GT22-C","GT83-C"]
gtGrouped = gta0+gta1+gtb0+gtb1+gtb2+gtc0+gtc1+gtc2

# %% [markdown]
# ## Main folds

# %%
## Reading in the reconstruction error data
train_all=pd.read_csv("../Datasets/RE_data/rerr_gtAll_training.csv")
train_all.columns = ['Family', 'Err']
test_all=pd.read_csv("../Datasets/gtu/gtu.RE_all.csv")

# %%
test_all.groupby('Family').median()
# Out:
#               Err
# Family
# GT100-u  0.115246
# GT101-u  0.111683
# GT102-u  0.104105
# GT103-u  0.102328
# GT105-u  0.085370
# GT106-u  0.093037
# GT107-u  0.102565
# GT108-u  0.281884
# GT109-u  0.096032
# GT11-u   0.114253
# GT110-u  0.087367
# GT26-u   0.132333
# GT29-u   0.098119
# GT42-u   0.107304
# GT44-u   0.114815
# GT48-u   0.116406
# GT53-u   0.084841
# GT69-u   0.102770
# GT71-u   0.104204
# GT73-u   0.125388
# GT74-u   0.120559
# GT76-u   0.091351
# GT89-u   0.091285
# GT91-u   0.136016
# GT92-u   0.116445
# GT95-u   0.113756
# GT96-u   0.130178
# GT97-u   0.146374
# GT98-u   0.107749
# GT99-u   0.120120

# %% [markdown]
# ### Fit extreme value distribution to the training error distribution

# %%
train=train_all
test=test_all
# test=test_all.loc[test_all['family']=='GT110-u']
(c,log,scale,fig,ax)=Plot_Dist_Train_Extreme(train,test,bin1=500,bin2=200,interval1=0.95,interval2=0.99)
# Out:
# 95% CI upper bound: 0.10659970165381911
# 99% CI upper bound: 0.14685000308245982
# Median RE: 0.10394361615180968

# %%
fig.savefig("../ExampleOutputs/gtu.hist.svg",dpi=300)
# fig.savefig("../output/all_GT110-u.svg",dpi=300)

# %%
train=train_all
test=test_all.loc[test_all['Family']=='GT110-u']
(c,log,scale,fig,ax)=Plot_Dist_Train_Extreme(train,test,bin1=500,bin2=80,interval1=0.95,interval2=0.99)
# Out:
# 95% CI upper bound: 0.10659970165381911
# 99% CI upper bound: 0.14685000308245982
# Median RE: 0.08736687898635864

# %%
fig.savefig("../ExampleOutputs/GT110.hist.svg",dpi=300)

# %% [markdown]
# ### Boxplot

# %%
## Generate a boxplot with both training and testing data
test_here=test_all
train_all_fold=train_all.copy() # train_all
train_all_fold['Family']=train_all_fold['Family'].map(lambda x: x.split('-')[1])
data = pd.concat([train_all_fold, test_here]) 
ordered_list=test_here.groupby('Family').median().sort_values('Err').index.tolist()
ordered_list[:0] = ['A','B','C','lyso']
#sns.violinplot(x='fold', y='Err', data=r_err_Au.loc[r_err_Au['Err']<1])
#sns.violinplot(x='fold', y='Err', data=r_err_Au)
plt.figure(figsize=(15,15))
g=sns.boxplot(x='Err', y='Family', data=data,order=ordered_list)
# g=sns.catplot(x="Err", y="fold",data=data,order=ordered_list)
g.axvline(0.107, alpha = 0.9, linestyle = ":",linewidth=3,color="red")
g.axvline(0.117, alpha = 0.9, linestyle = ":",linewidth=1,color="blue")
g.axvline(0.127, alpha = 0.9, linestyle = ":",linewidth=1,color="blue")
g.axvline(0.147, alpha = 0.9, linestyle = ":",linewidth=3,color="red")
# sns.boxplot(x="distance", y="method", data=planets,
#             whis=[0, 100], width=.6, palette="vlag")
# g.set_xticklabels(rotation=30)
g.set_xlim(0,0.5)
# Out:
# (0.0, 0.5)

# %%
g.figure.savefig("../ExampleOutputs/all_gtu.boxplot.svg",dpi=300)

# %%
pwd
# Out:
# '/Users/rtaujale/Dropbox (Edison_Lab@UGA)/Projects/GT_informatics/GT/GT_strML/finalized_v1/code'

# %%
## Print medians or quantiles for every fold/family
df=test_all
# df.groupby('fold').mean().reset_index()[df['fold'] in gtu]
df1=df.groupby('Family').median().reset_index().sort_values('Err')
df1
# Out:
#      Family       Err
# 15   GT53-u  0.084841
# 4   GT105-u  0.085370
# 9   GT110-u  0.087367
# 21   GT89-u  0.091285
# 20   GT76-u  0.091351
# 5   GT106-u  0.093037
# 7   GT109-u  0.096032
# 11   GT29-u  0.098119
# 3   GT103-u  0.102328
# 16   GT69-u  0.102770
# 2   GT102-u  0.104105
# 17   GT71-u  0.104204
# 12   GT42-u  0.107304
# 27   GT98-u  0.107749
# 1   GT101-u  0.111683
# 24   GT95-u  0.113756
# 8    GT11-u  0.114253
# 13   GT44-u  0.114815
# 0   GT100-u  0.115246
# 14   GT48-u  0.116406
# 23   GT92-u  0.116445
# 28   GT99-u  0.120120
# 19   GT74-u  0.120559
# 18   GT73-u  0.125388
# 25   GT96-u  0.130178
# 10   GT26-u  0.132333
# 22   GT91-u  0.136016
# 26   GT97-u  0.146374
# 6   GT108-u  0.281884

# %% [markdown]
# ## Clusters

# %% [markdown]
# ### Reading in the data files

# %%
pwd
# Out:
# '/Users/rtaujale/Dropbox (Edison_Lab@UGA)/Projects/GT_informatics/GT/GT_strML/Github_Folder/GT-CNN/Codes'

# %%
grp=['gta0','gta1','gtb0','gtb1','gtb2','gtc0','gtc1','gtc2','gtlyso']

# %%
# Read in the test and training rec err from files
# grp=['gta0','gta1','gta2','gtb0','gtb1','gtb2','gtc0','gtc1','gtlyso']
grp=['gta0','gta1','gtb0','gtb1','gtb2','gtc0','gtc1','gtc2','gtlyso']
# grp=['gta0','gta1','gta2','gtb0','gtb1','gtb2']
train_data=dict()
test_data=dict()
test_data1=dict()
unknown_data=dict()
for i in grp:
    train="../Datasets/RE_data/rerr_"+i+"_training.csv"
    ooc="../Datasets/RE_data/rerr_"+i+"_ooc.csv"
    oof="../Datasets/RE_data/rerr_"+i+"_oof.csv"
    unknown="../Datasets/gtu/gtu.RE_"+i+".csv"
    
    train_data[i]=pd.read_csv(train)
    ooc_data[i]=pd.read_csv(ooc)
    oof_data[i]=pd.read_csv(oof)
    unknown_data[i]=pd.read_csv(unknown)

# %%
unknown_data['gtb0'].groupby('Family').mean().sort_values('Err')
# Out:
#               Err
# Family
# GT106-u  0.208285
# GT110-u  0.208842
# GT103-u  0.225448
# GT109-u  0.229606
# GT102-u  0.239036
# GT71-u   0.242249
# GT29-u   0.257291
# GT69-u   0.272877
# GT101-u  0.276589
# GT99-u   0.278366
# GT42-u   0.281224
# GT89-u   0.283501
# GT96-u   0.288315
# GT100-u  0.299659
# GT95-u   0.301628
# GT48-u   0.314411
# GT44-u   0.320787
# GT73-u   0.321660
# GT97-u   0.324360
# GT26-u   0.325958
# GT11-u   0.333928
# GT92-u   0.336931
# GT74-u   0.346839
# GT98-u   0.353378
# GT91-u   0.369042
# GT53-u   0.488991
# GT105-u  0.629228
# GT76-u   0.629321
# GT108-u  0.916613

# %% [markdown]
# ### Generate sub groups of val, test and gtu datasets for each cluster

# %%
## Need to read the AllTest file with test results for all families except training

# %%
grp
# Out:
# ['gta0', 'gta1', 'gtb0', 'gtb1', 'gtb2', 'gtc0', 'gtc1', 'gtc2', 'gtlyso']

# %%
# test_val = ooc ooc_data
# test_neg = oof oof_data
# test_gtu =     unknown_data

# %%
## Need the following
#train_data[i] # SC = RE for training data 
#test_val[i] # OOC = RE for out of cluster but same families (gta1, unclassified for gta0)
#test_neg[i] # OOF = RE for negative families (B,C for A)
#test_gtu[i] # GTu = GT-us from the original set
#unknown_data[i] # GTu = new set of GT-us

# %% [markdown]
# ### Plotting distributions

# %%
# Plot all clusters
for i in grp:
    plt.figure(figsize=(30,10))
    plt.hist(np.asarray(train_data[i]["Err"], dtype=float),bins=100,alpha=0.7, density=True)
    plt.hist(np.asarray(test_val[i]["Err"]), alpha=0.35, bins=200, density=True)
    plt.hist(np.asarray(test_neg[i]["Err"]), alpha=0.35, bins=1000, density=True)
    # plt.hist(np.asarray(unknown_data["gta0"]["Err"]), edgecolor='k', alpha=0.35, bins=1000, density=True)
    plt.xlim(0,2)
    plt.title(i)
    plt.close
    figname="autoencoder_sub_dist"+i+".svg"
    plt.savefig(figname,dpi=300)

# %% [markdown]
# ### Generate SC, OOC and OOF values

# %%
## Calculate appropriate central tendency measures for each RE distribution
re_values=dict()
re_values['SC']=dict()
re_values['OOC']=dict()
re_values['OOF']=dict()
for i in grp:
    re_values['SC'][i]=train_data[i].median().values[0]
    re_values['OOC'][i]=ooc_data[i].mean().values[0]
    re_values['OOF'][i]=oof_data[i].mean().values[0]

re_values['OOC']['gta0']=ooc_data['gta0'].median().values[0]
re_values['OOC']['gta1']=ooc_data['gta1'].median().values[0]
re_values['OOC']['gtb0']=ooc_data['gtb0'].median().values[0]
re_values['OOC']['gtb1']=ooc_data['gtb1'].median().values[0]
re_values['OOF']['gtb0']=ooc_data['gtb0'].median().values[0]
re_values['OOF']['gtc0']=ooc_data['gtc0'].median().values[0]
re_values['OOF']['gtc1']=ooc_data['gtc1'].median().values[0]

re_values
# Out:
# {'SC': {'gta0': 0.1258273422718048,
#   'gta1': 0.08553256094455719,
#   'gtb0': 0.09493278712034224,
#   'gtb1': 0.11197581887245178,
#   'gtb2': 0.1497340202331543,
#   'gtc0': 0.21322201192379,
#   'gtc1': 0.28307750821113586,
#   'gtc2': 0.26864010095596313,
#   'gtlyso': 0.11339077353477478},
#  'OOC': {'gta0': 0.22212222963571548,
#   'gta1': 0.28409597277641296,
#   'gtb0': 0.1962147057056427,
#   'gtb1': 0.3264983892440796,
#   'gtb2': 0.7066207815627319,
#   'gtc0': 0.3917275443592761,
#   'gtc1': 0.5887653968946496,
#   'gtc2': 0.5867838928576794,
#   'gtlyso': 0.1973829814041867},
#  'OOF': {'gta0': 0.3223292794058654,
#   'gta1': 0.38974644056127133,
#   'gtb0': 0.1962147057056427,
#   'gtb1': 0.48088257950931906,
#   'gtb2': 0.9202121077084429,
#   'gtc0': 0.36065229773521423,
#   'gtc1': 0.5654787421226501,
#   'gtc2': 1.018041508801583,
#   'gtlyso': 0.4814248231262168}}

# %%
## Fit a distribution (EVD for training, Gaussian for OOC and OOF)
def fit_subRE(train,ooc,oof,clust):
    dat1=np.array(train[clust]["Err"], dtype=float)
    dat2=np.array(ooc[clust]["Err"], dtype=float).reshape(-1, 1)
    dat3=np.array(oof[clust]["Err"], dtype=float).reshape(-1, 1)

    median = np.median(dat1)
    c, loc, scale = genextreme.fit(dat1, floc=median)
    train_data_par=genextreme.mean(c,loc,scale)
#     if (clust in ['gtb0']):
#         nc=2
#     else:
#         nc=1
#     if (clust in ['gtlyso']):
#         nc=1
#     elif (clust in ['gta0','gta1']):
#         nc=2
#     elif (clust in ['gtb0','gtb1','gtb2','gtc0','gtc1','gtc2']):
#         nc=3
    nc=1
    gmm1 = GaussianMixture(n_components=nc, random_state=2020)
    gmm1.fit(dat2)
    test_val_par=np.mean(gmm1.means_)#[0][0]
#     else:
#         gmm1 = GaussianMixture(n_components=1, random_state=2020)
#         gmm1.fit(dat2)
#         test_val_par=gmm1.means_[0][0]

    gmm2 = GaussianMixture(n_components=1, random_state=2020)
    gmm2.fit(dat3)
    test_neg_par=gmm2.means_[0][0]
    
    return(train_data_par,test_val_par,test_neg_par)

# fit_subRE(train_data,test_val,test_neg,'gtb0')
re_values=dict()
re_values['SC']=dict()
re_values['OOC']=dict()
re_values['OOF']=dict()
for i in grp:
    (re_values['SC'][i],re_values['OOC'][i],re_values['OOF'][i])=fit_subRE(train_data,test_val,test_neg,i)
re_values
# Out:
# /Users/rtaujale/opt/anaconda3/envs/GTstrML/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:2594: RuntimeWarning: invalid value encountered in power
#   np.sign(c)*(-g3 + (g2 + 2*g2mg12)*g1)/g2mg12**1.5,
# {'SC': {'gta0': 0.14501293974945387,
#   'gta1': 0.11035127256724281,
#   'gtb0': 0.10832370575070521,
#   'gtb1': 0.14974306067700144,
#   'gtb2': 0.177513692423049,
#   'gtc0': 0.2547162731772906,
#   'gtc1': 0.3293499685264941,
#   'gtc2': 0.3082910218902991,
#   'gtlyso': 0.18398079119266747},
#  'OOC': {'gta0': 0.24364851573095894,
#   'gta1': 0.2953052853919425,
#   'gtb0': 0.2276490337960422,
#   'gtb1': 0.3727700505778799,
#   'gtb2': 0.7066207815627319,
#   'gtc0': 0.3917275443592761,
#   'gtc1': 0.5887653968946496,
#   'gtc2': 0.5867838928576794,
#   'gtlyso': 0.1973829814041867},
#  'OOF': {'gta0': 0.3223292794058654,
#   'gta1': 0.38974644056127133,
#   'gtb0': 0.3444296994562847,
#   'gtb1': 0.48088257950931906,
#   'gtb2': 0.9202121077084429,
#   'gtc0': 0.7952218985533586,
#   'gtc1': 1.168456332921431,
#   'gtc2': 1.018041508801583,
#   'gtlyso': 0.4814248231262168}}

# %%
re_values['OOC']['gta0']=test_val['gta0'].median().values[0]
re_values['OOC']['gta1']=test_val['gta1'].median().values[0]
re_values['OOC']['gtb0']=test_val['gtb0'].median().values[0]
re_values['OOC']['gtb1']=test_val['gtb1'].median().values[0]
re_values['OOF']['gtb0']=test_val['gtb0'].median().values[0]
re_values['OOF']['gtc0']=test_val['gtc0'].median().values[0]
re_values['OOF']['gtc1']=test_val['gtc1'].median().values[0]
re_values['OOF']['gtc2']=test_val['gtc2'].median().values[0]

# %%
dat1=np.array(test_val['gtb1']["Err"], dtype=float)
median = np.median(dat1)
c, loc, scale = genextreme.fit(dat1, floc=median)
genextreme.mean(c,loc,scale)
# Out:
# 0.40581563159605233

# %%
dat2
# Out:
# array([[0.30049542, 0.30840224, 0.20496245, ..., 0.2329303 , 0.16954093,
#         0.19826259]])

# %%
re_values
# Out:
# {'SC': {'gta0': 0.1258273422718048,
#   'gta1': 0.09889166802167892,
#   'gtb0': 0.09493278712034224,
#   'gtb1': 0.11197581887245178,
#   'gtb2': 0.1497340202331543,
#   'gtc0': 0.21322201192379,
#   'gtc1': 0.28307750821113586,
#   'gtc2': 0.26864010095596313,
#   'gtlyso': 0.11339077353477478},
#  'OOC': {'gta0': 0.24364851573095894,
#   'gta1': 0.34211286902427673,
#   'gtb0': 0.1962147057056427,
#   'gtb1': 0.3264983892440796,
#   'gtb2': 0.7066207815627319,
#   'gtc0': 0.3917275443592761,
#   'gtc1': 0.5887653968946496,
#   'gtc2': 0.5867838928576794,
#   'gtlyso': 0.1973829814041867},
#  'OOF': {'gta0': 0.3223292794058654,
#   'gta1': 0.42785647260677123,
#   'gtb0': 0.1962147057056427,
#   'gtb1': 0.48088257950931906,
#   'gtb2': 0.9202121077084429,
#   'gtc0': 0.36065229773521423,
#   'gtc1': 0.5654787421226501,
#   'gtc2': 0.5186419486999512,
#   'gtlyso': 0.4814248231262168}}

# %% [markdown]
# ### Calculate Cluster Assignment Score

# %%
testHere=unknown_data # test_gtu unknown_data
col='Family' # 'fold' # 'Family'
allgtu=list()
allgtu.append(testHere[i].groupby(col).mean().reset_index()[col].tolist())
grpname=['Fam']
for i in grp:
    grpname.append(i)
    allgtu.append(testHere[i].groupby(col).mean()['Err'].tolist())
#     allgtu[i]=test_gtu[i].groupby('fold').mean()['Err']
gtu_resub=pd.DataFrame(np.asarray(allgtu).T, columns=grpname)
{
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row15_col7 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row16_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row17_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row18_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row19_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row20_col7 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row21_col6 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row22_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row23_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row24_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row25_col2 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row26_col3 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row27_col6 {
#             background-color:  lightgreen;
#         }    #T_4727f9ac_852d_11eb_83cb_8c85902c7663row28_col3 {
#             background-color:  lightgreen;
#         }</style><table id="T_4727f9ac_852d_11eb_83cb_8c85902c7663" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fam</th>        <th class="col_heading level0 col1" >gta0</th>        <th class="col_heading level0 col2" >gta1</th>        <th class="col_heading level0 col3" >gtb0</th>        <th class="col_heading level0 col4" >gtb1</th>        <th class="col_heading level0 col5" >gtb2</th>        <th class="col_heading level0 col6" >gtc0</th>        <th class="col_heading level0 col7" >gtc1</th>        <th class="col_heading level0 col8" >gtc2</th>        <th class="col_heading level0 col9" >gtlyso</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4727f9ac_852d_11eb_83cb_8c85902c7663level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col0" class="data row0 col0" >GT100-u</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col1" class="data row0 col1" >-0.557237</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col2" class="data row0 col2" >-0.312849</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col3" class="data row0 col3" >-0.339798</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col4" class="data row0 col4" >-0.558917</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col5" class="data row0 col5" >-0.273806</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col6" class="data row0 col6" >-4.503501</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col7" class="data row0 col7" >-3.298445</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col8" class="data row0 col8" >-1.001058</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row0_col9" class="data row0 col9" >-1.129790</td>
#             </tr>
#             <tr>
#                         <th id="T_4727f9ac_852d_11eb_83cb_8c85902c7663level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col0" class="data row1 col0" >GT101-u</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col1" class="data row1 col1" >-0.443984</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col2" class="data row1 col2" >-0.234940</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col3" class="data row1 col3" >-0.242744</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col4" class="data row1 col4" >-0.313135</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col5" class="data row1 col5" >-0.207072</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col6" class="data row1 col6" >-3.407691</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col7" class="data row1 col7" >-2.572243</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col8" class="data row1 col8" >-0.761732</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row1_col9" class="data row1 col9" >-0.957109</td>
#             </tr>
#             <tr>
#                         <th id="T_4727f9ac_852d_11eb_83cb_8c85902c7663level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col0" class="data row2 col0" >GT102-u</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col1" class="data row2 col1" >-0.371345</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col2" class="data row2 col2" >-0.196058</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col3" class="data row2 col3" >0.094080</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col4" class="data row2 col4" >-0.200823</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col5" class="data row2 col5" >-0.027905</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col6" class="data row2 col6" >-3.137151</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col7" class="data row2 col7" >-2.288942</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col8" class="data row2 col8" >-0.716991</td>
#                         <td id="T_4727f9ac_852d_11eb_83cb_8c85902c7663row2_col9" class="data row2 col9" >-0.872662</td>
#             </tr>
#             <tr>
#                         <th id="T_4727f9ac_852d_11eb_83cb_8c85902c7663level0_row3" c

# %%
subscore1=gtu_resub.apply(calcSubScore,axis=1)
subscore1.columns=grp
subscore1.insert(loc=0, column='Fam', value=gtu_resub['Fam'])
subscore1=subscore1.set_index('Fam')
subscore1.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-86387161905c> in <module>
#      14 #         print(row['Fam'],cname,score)
#      15     return(pd.Series(allval))
# ---> 16 subscore1=gtu_resub.apply(calcSubScore,axis=1)
#      17 subscore1.columns=grp
#      18 subscore1.insert(loc=0, column='Fam', value=gtu_resub['Fam'])
#
# NameError: name 'gtu_resub' is not defined

# %%
subscore1.values
# Out:
# array([[-5.57237004e-01, -3.12849032e-01, -3.39797720e-01,
allgtu.append(testHere[i].groupby(col).mean().reset_index()[col].tolist())
grpname=['Fam']
for i in grp:
    grpname.append(i)
    allgtu.append(testHere[i].groupby(col).mean()['Err'].tolist())
#     allgtu[i]=test_gtu[i].groupby('fold').mean()['Err']
gtu_resub=pd.DataFrame(np.asarray(allgtu).T, columns=grpname)
gtu_resub
# Out:
#        Fam                 gta0                 gta1                 gtb0  \
# 0  GT107-u  0.25116106034733177   0.2614165759227407  0.17563013356970988
# 1  GT111-u  0.31357292885843074  0.43047840067169124  0.36096869660051245
# 2  GT112-u  0.23865563137566342   0.2269898534697645  0.21410638378823504
# 3  GT113-u   0.3226620552507607  0.38233931394847664  0.18608926494379302
# 4  GT114-u   0.2720945477485657   0.3029194378427097  0.20070426485368184
#
#                   gtb1                gtb2                gtc0  \
# 0   0.3199436324318563  0.6004484873118363  0.6605265806979081
# 1   0.6312814528482003   1.144007098465635  1.0475978066001022
# 2   0.4537808649680194  0.7239271963343901  0.8797259742722792
# 3  0.40060297556825586  0.6842327330563519  0.9215438607576731
# 4   0.4394786996500833  0.7778024205139705  0.8719526614461627
#
#                  gtc1                gtc2              gtlyso
# 0  0.9458345686356853  0.7839228848772725  0.3015945682844778
# 1  1.5247642621659396    1.35051716524258  0.5580127351116716
# 2   1.281324119252317  1.1042189668206608  0.3449172051075627
# 3  1.3132097795202926   1.214575232364036  0.6062209232433422
# 4  1.2976756308759962  1.1606038468224662  0.5066877624818257

# %%
subscore2=gtu_resub.apply(calcSubScore,axis=1)
subscore2.columns=grp
subscore2.insert(loc=0, column='Fam', value=gtu_resub['Fam'])
subscore2=subscore2.set_index('Fam')
subscore2.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
#     #T_60eec334_852d_11eb_83cb_8c85902c7663row0_col2 {
#             background-color:  lightgreen;
#         }    #T_60eec334_852d_11eb_83cb_8c85902c7663row1_col0 {
#             background-color:  lightgreen;
#         }    #T_60eec334_852d_11eb_83cb_8c85902c7663row2_col1 {
#             background-color:  lightgreen;
#         }    #T_60eec334_852d_11eb_83cb_8c85902c7663row3_col2 {
#             background-color:  lightgreen;
#         }    #T_60eec334_852d_11eb_83cb_8c85902c7663row4_col2 {
#             background-color:  lightgreen;
#         }</style><table id="T_60eec334_852d_11eb_83cb_8c85902c7663" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >gta0</th>        <th class="col_heading level0 col1" >gta1</th>        <th class="col_heading level0 col2" >gtb0</th>        <th class="col_heading level0 col3" >gtb1</th>        <th class="col_heading level0 col4" >gtb2</th>        <th class="col_heading level0 col5" >gtc0</th>        <th class="col_heading level0 col6" >gtc1</th>        <th class="col_heading level0 col7" >gtc2</th>        <th class="col_heading level0 col8" >gtlyso</th>    </tr>    <tr>        <th class="index_name level0" >Fam</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60eec334_852d_11eb_83cb_8c85902c7663level0_row0" class="row_heading level0 row0" >GT107-u</th>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col0" class="data row0 col0" >-0.227779</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col1" class="data row0 col1" >-0.005449</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col2" class="data row0 col2" >0.123240</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col3" class="data row0 col3" >-0.062232</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col4" class="data row0 col4" >0.057801</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col5" class="data row0 col5" >-1.903228</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col6" class="data row0 col6" >-1.344404</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col7" class="data row0 col7" >-0.343062</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row0_col8" class="data row0 col8" >-0.363157</td>
#             </tr>
#             <tr>
#                         <th id="T_60eec334_852d_11eb_83cb_8c85902c7663level0_row1" class="row_heading level0 row1" >GT111-u</th>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col0" class="data row1 col0" >-0.545393</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col1" class="data row1 col1" >-0.561183</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col2" class="data row1 col2" >-1.706687</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col3" class="data row1 col3" >-0.906179</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col4" class="data row1 col4" >-0.647682</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col5" class="data row1 col5" >-4.528681</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col6" class="data row1 col6" >-3.394429</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col7" class="data row1 col7" >-1.099124</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row1_col8" class="data row1 col8" >-1.059881</td>
#             </tr>
#             <tr>
#                         <th id="T_60eec334_852d_11eb_83cb_8c85902c7663level0_row2" class="row_heading level0 row2" >GT112-u</th>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col0" class="data row2 col0" >-0.164139</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col1" class="data row2 col1" >0.107717</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col2" class="data row2 col2" >-0.256652</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col3" class="data row2 col3" >-0.425026</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col4" class="data row2 col4" >-0.102462</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col5" class="data row2 col5" >-3.390028</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col6" class="data row2 col6" >-2.532393</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col7" class="data row2 col7" >-0.770465</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row2_col8" class="data row2 col8" >-0.480871</td>
#             </tr>
#             <tr>
#                         <th id="T_60eec334_852d_11eb_83cb_8c85902c7663level0_row3" class="row_heading level0 row3" >GT113-u</th>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col0" class="data row3 col0" >-0.591648</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col1" class="data row3 col1" >-0.402942</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col2" class="data row3 col2" >0.019973</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col3" class="data row3 col3" >-0.280876</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col4" class="data row3 col4" >-0.050943</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col5" class="data row3 col5" >-3.673674</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col6" class="data row3 col6" >-2.645302</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col7" class="data row3 col7" >-0.917724</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row3_col8" class="data row3 col8" >-1.190870</td>
#             </tr>
#             <tr>
#                         <th id="T_60eec334_852d_11eb_83cb_8c85902c7663level0_row4" class="row_heading level0 row4" >GT114-u</th>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col0" class="data row4 col0" >-0.334310</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col1" class="data row4 col1" >-0.141876</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col2" class="data row4 col2" >-0.124327</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col3" class="data row4 col3" >-0.386257</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col4" class="data row4 col4" >-0.172386</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col5" class="data row4 col5" >-3.337303</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col6" class="data row4 col6" >-2.590294</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col7" class="data row4 col7" >-0.845704</td>
#                         <td id="T_60eec334_852d_11eb_83cb_8c85902c7663row4_col8" class="data row4 col8" >-0.920424</td>
#             </tr>
#     </tbody></table>

# %%
# Plot distribution of training vs test
scname='gtc0'
famname='GT89-u'
trainSC=train_data[scname]
# Plotting based in 
# testSC=test_data[scname]
# For plotting specific family within test results
test_here=unknown_data[scname]
testSC=test_here[test_here['Family'].str.contains(famname)]

trainSC=train_data[scname]+test_val[scname]
trainSC=train_data[scname]
# testSC=test_here
(fig,ax)=Plot_Dist_SubClust_Extreme(trainSC,testSC,400,100)
ax.set_ylim(0,30)
ax.set_xlim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
ax.figure.savefig("gtc0_gt89.svg",dpi=300)

# %%
pwd
# Out:
# '/Users/rtaujale/Dropbox (Edison_Lab@UGA)/Projects/GT_informatics/GT/GT_strML/finalized_v1/code'

# %% [markdown]
# ### Calculate Median weighted RE

# %%
for subclust in grp:
    train=train_data[subclust]
    test=test_data[subclust]
    grouped = test.groupby('Family') # ('fold')#
    integral_list = []
    valsSubClust[subclust]=dict()
    for name, group in grouped:
        print(name, end =" ")
#         print(group['Err'].median(), end =" ")
    print()
# Out:
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u
# GT100-u GT101-u GT102-u GT103-u GT105-u GT106-u GT108-u GT109-u GT11-u GT110-u GT26-u GT29-u GT42-u GT44-u GT48-u GT53-u GT69-u GT71-u GT73-u GT74-u GT76-u GT89-u GT91-u GT92-u GT95-u GT96-u GT97-u GT98-u GT99-u

# %%
test_data['gta0']
# Out:
#                                                  Name Fold  Family       Err
# 0     GT44-u|QCV10367|E.coliO157H7ECP17-1298_Bacteria    u  GT44-u  0.510915
# 1           GT44-u|ADH94633|C.difficile55767_Bacteria    u  GT44-u  0.442626
# 2          GT44-u|ADH94634|C.difficileCH6230_Bacteria    u  GT44-u  0.412049
# 3          GT44-u|ADH94625|C.difficileCH6223_Bacteria    u  GT44-u  0.365227
# 4        GT44-u|AVE48566|S.marcescensAR_0027_Bacteria    u  GT44-u  0.415944
# ..                                                ...  ...     ...       ...
# 70     GT44-u|VEF11672|P.fluorescensNCTC9428_Bacteria    u  GT44-u  0.757558
# 71  GT44-u|SDN45601|P.arsenicoxydansCECT7543_Bacteria    u  GT44-u  0.366445
# 72          GT44-u|SYZ82990|V.choleraeNCTC30_Bacteria    u  GT44-u  0.683351
# 73                   GT44-u|SIR68046|P.spB10_Bacteria    u  GT44-u  0.362965
# 74            GT44-u|CAG18682|P.profundumSS9_Bacteria    u  GT44-u  1.032876
#
# [75 rows x 4 columns]

# %%
test_data['gta0']=test_data['gta0'][(test_data['gta0']['Err']<0.6) ]

# %% [markdown]
# ### Calculate Weighted Overlap Scores

# %%
test_data=test_gtu

# %%
# Calculates overlap Scores for test data using multiple bin sizes against each subcluster and puts them into a dict
valsSubClust=dict()
binslist=[10,25,50,75,100,125,150,175,200,225,250,275,300]
for subclust in grp:
    train=train_data[subclust]
    test=test_data[subclust]
    grouped = test.groupby('fold') # ('fold') # Family
    integral_list = []
    valsSubClust[subclust]=dict()
    for name, group in grouped:
#         if (name =="GT110-u"):
        valsSubClust[subclust][name]=list()
        for b1 in binslist:
            for b2 in binslist:
                overlap =  Integral(train, group,bin1=b1,bin2=b2, figure=False)
                valsSubClust[subclust][name].append(overlap)

# %%
# Collects a rolling mean max of the overlap scores from multiple bin sizes for the final score
# Stores one final overlap score for each family type against each cluster.
# Prints out raw overlap scores as a table that can be copy-pasted if want to look at raw scores
# Do not use these raw scores for fold prediction. Need to be weighted by cluster negative overlap scores.
fam=test_data['gta0']['fold'].unique().tolist() # Family fold
ovsc=dict()
for i1,g in enumerate(fam):
    print(g,",", end =" ")
    ovsc[g]=list()
    for i2,r in enumerate(grp):
        if g in valsSubClust[r].keys():
            lst=valsSubClust[r][g]
            maxval=float(pd.DataFrame(lst).rolling(window=7).mean().max())
            ovsc[g].append(maxval)
            print(maxval,",", end =" ")
        else:
            ovsc[g].append("-")
            print("-,", end =" ")
    print()
# Out:
# array([0.35824206, 0.26046991, 0.29676306, 0.33085171, 0.27236303,
#        0.199931  , 0.20284136, 0.16909156, 0.28482532])

# %%
#neg_ovsc=[0.338967241,0.473146927,0.320874273,1.050902465,0.942520441,0.795187878,1.168406345,1.017997956,0.28482532]
neg_ovsc=[0.1258273422718048,0.09887388348579408,0.09493278712034224,0.10935643315315248,0.1497340202331543,0.21322201192379,0.28307750821113586,0.26864010095596313,0.11339077353477478]
#neg_ovsc=[0.22212222963571548,0.29376932978630066,0.1962147057056427,0.3498431444168091,0.6183708906173706,0.36065229773521423,0.5654787421226501,0.5186419486999512,0.15399868786334991]
#neg_ovsc=[0.29801681637763977,0.33351588249206543,0.322651743888855,0.4133259952068329,0.7992845177650452,0.737147331237793,1.0622998476028442,0.954084187746048,0.45547516644001007]

# %%
# Subtract cluster negative overlap scores from each cluster to generate weighted overlap scores.
# Stores them in a dict 
# Also prints out for copy-pasting

# Interpretaion:
#   The cluster with the highest score is the most likely cluster
#   If score above 0.12 then high or medium confidence.
#   Otherwise low confidence.
print("Final weighted overlap scores for each GT cluster:")
final_ovsc=dict()
for fam in ovsc.keys(): #ovsc.keys(): ['GT110-u']: 
    final_ovsc[fam]=list()
    print(fam, end=" ")
    for i,val in enumerate(ovsc[fam]):
        ovsc_norm=val-neg_ovsc[i]
        final_ovsc[fam].append(ovsc_norm)
        print(ovsc_norm,end=" ")
    print()
# Out:
# Final weighted overlap scores for each GT cluster:
# GT69-u 0.23961236495112953 0.30349497451801893 0.2418028798505783 0.07420924904199512 -0.006613290841904013 -0.04277249092157917 -0.15003435599646706 -0.12066786858475376 0.1648587643449254
# GT73-u 0.16741235677662836 0.206624162686862 0.22394405628229958 0.07314512127414198 -0.022763179442944648 -0.08548872825830295 -0.1472475042030162 -0.13314062380378297 0.11734740775130667
# GT48-u 0.21306074836593697 0.1519291435481443 0.15795419713783793 0.1989840145663681 -0.011572679099243116 0.04824993017769194 -0.091459317627816 -0.029236159571008252 0.2089171998564368
# GT44-u 0.2626150431969911 0.1530000378512938 0.21964247003304044 0.198363571979142 -0.0014623311765812053 0.0358229167821556 -0.0766658096734529 -0.04179332359767682 0.168486642094066
# GT42-u 0.27946702078086705 0.2641353615380869 0.3542429688915279 0.21944766818244804 0.05125613940771259 -0.005004021970409056 -0.12129965351989522 -0.09178754175046272 0.19108447152333963
# GT89-u 0.2638693656814744 0.13815313695023973 0.21639859194897498 0.23425698474798706 0.007738628876769182 0.11841779771134395 0.03094089035111297 -0.014825831620042862 0.2199590363297994
# GT53-u 0.198522395834689 0.13012424000327666 0.10381311960921956 0.14133743742429444 -0.04516295771779748 0.09187913313278748 -0.08461181642260951 -0.039818347005561666 0.13391632110087495
# GT26-u 0.25004878921526613 0.18062491949899717 0.29307903805840374 0.13624047841429238 -0.00011291891139664223 -0.02623503183710546 -0.11309021345751238 -0.08056856330117643 0.13227900728495115
# GT97-u 0.1313164731293221 0.10896911509977876 0.2778648218844543 0.08328287269732688 -0.04247457673867275 -0.0733915034492138 -0.14064218762620898 -0.10842819010466606 0.10342385425476744
    test_data1[i]=test_data1[i][~test_data1[i]["Name"].isin(rem)]

# %%
test_data1['gtb0'].shape
# Out:
# (22, 4)

# %%
df=test_data['gtb0']#['GT101-u']
df[df['Family']=='GT101-u'].sort_values('Err')
# Out:
#                                                    Name Fold   Family  \
# 3659           GT101-u|AYE39026|L.spHBUAS52074_Bacteria    u  GT101-u
# 3624  GT101-u|AKM77825|C.WolfebacteriabacteriumGW201...    u  GT101-u
# 3674  GT101-u|AAO75156|B.thetaiotaomicronVPI-5482_Ba...    u  GT101-u
# 3594  GT101-u|QAV44614|P.agglomeransCFSAN047154_Bact...    u  GT101-u
# 3613           GT101-u|AWP32933|P.vagansFBS135_Bacteria    u  GT101-u
# ...                                                 ...  ...      ...
# 3590        GT101-u|AAK75842|S.pneumoniaeTIGR4_Bacteria    u  GT101-u
# 3616          GT101-u|AZR14904|L.crispatusAB70_Bacteria    u  GT101-u
# 3620              GT101-u|AUA18822|S.suisAH681_Bacteria    u  GT101-u
# 3641   GT101-u|QFR68412|L.paralimentariusLP238_Bacteria    u  GT101-u
# 3640   GT101-u|VTQ08300|S.daejeonenseNCTC13534_Bacteria    u  GT101-u
#
#            Err
# 3659  0.119929
# 3624  0.128484
# 3674  0.131662
# 3594  0.133996
# 3613  0.136896
# ...        ...
# 3590  0.250064
# 3616  0.253480
# 3620  0.300300
# 3641  0.329666
# 3640  0.400738
#
# [97 rows x 4 columns]

# %%
test_data1['gtb0']=test_data1['gtb0'][test_data1['gtb0']['Err']>0.14]

# %%
test_data1['gtlyso'].sort_values('Err')
# Out:
#                                                Name Fold  Family       Err
# 2667            GT69-u|ADV25434|C.gattiiWM276_Fungi    u  GT69-u  0.136307
# 1808          GT69-u|CAK48847|A.nigerCBS51388_Fungi    u  GT69-u  0.149749
# 1561   GT69-u|QDZ18543|C.primusCCMP1205_Chlorophyta    u  GT69-u  0.160556
# 1509     GT69-u|ATY64188|C.militarisATCC34164_Fungi    u  GT69-u  0.166540
# 2542     GT69-u|VDB96428|B.graminisfsptritici_Fungi    u  GT69-u  0.184792
# 373            GT69-u|ATZ51704|B.cinereaB0510_Fungi    u  GT69-u  0.187798
# 1812          GT69-u|CAK44894|A.nigerCBS51388_Fungi    u  GT69-u  0.188412
# 3660          GT69-u|CAK47758|A.nigerCBS51388_Fungi    u  GT69-u  0.196337
# 908   GT69-u|ANM86623|C.uncialissubspuncialis_Fungi    u  GT69-u  0.200225
# 3674          GT69-u|CAK38727|A.nigerCBS51388_Fungi    u  GT69-u  0.206128
# 2344            GT69-u|ADV23259|C.gattiiWM276_Fungi    u  GT69-u  0.209086
# 3312            GT69-u|BAE64674|A.oryzaeRIB40_Fungi    u  GT69-u  0.212151
# 3646          GT69-u|CAK43148|A.nigerCBS51388_Fungi    u  GT69-u  0.213648
# 1767            GT69-u|BAE57178|A.oryzaeRIB40_Fungi    u  GT69-u  0.225531
# 1                GT69-u|AAC13946|C.neoformans_Fungi    u  GT69-u  0.246788
# 1560     GT69-u|ATY63210|C.militarisATCC34164_Fungi    u  GT69-u  0.249202
# 899            GT69-u|ATZ49942|B.cinereaB0510_Fungi    u  GT69-u  0.249381
# 3376     GT69-u|ATY61355|C.militarisATCC34164_Fungi    u  GT69-u  0.257547
# 1159          GT69-u|CAK38741|A.nigerCBS51388_Fungi    u  GT69-u  0.260629
# 3111            GT69-u|BAE59997|A.oryzaeRIB40_Fungi    u  GT69-u  0.275312
# 1059              GT69-u|CCD48824|B.cinereaT4_Fungi    u  GT69-u  0.298833
# 1407            GT69-u|BAE60536|A.oryzaeRIB40_Fungi    u  GT69-u  0.326933
# 0             GT69-u|AAY89392|C.gattiiVGIR265_Fungi    u  GT69-u  0.652149

# %%
# Calculates overlap Scores for test data using multiple bin sizes against each subcluster and puts them into a dict
valsSubClust=dict()
binslist=[10,25,50,75,100,125,150,175,200,225,250,275,300]
for subclust in grp:
    train=train_data[subclust]
    test=test_data1[subclust]
    grouped = test.groupby('Family') # ('fold')#
    integral_list = []
    valsSubClust[subclust]=dict()
    for name, group in grouped:
#         if (name =="GT110-u"):
        valsSubClust[subclust][name]=list()
        for b1 in binslist:
            for b2 in binslist:
                overlap =  Integral(train, group,bin1=b1,bin2=b2, figure=False)
                valsSubClust[subclust][name].append(overlap)

# %%
fam=test_data['gta0']['Family'].unique().tolist() # Family fold
fam=['GT69-u']
ovsc=dict()
for i1,g in enumerate(fam):
    print(g,",", end =" ")
    ovsc[g]=list()
    for i2,r in enumerate(grp):
        if g in valsSubClust[r].keys():
            lst=valsSubClust[r][g]
            maxval=float(pd.DataFrame(lst).rolling(window=7).mean().max())
            ovsc[g].append(maxval)
            print(maxval,",", end =" ")
        else:
            ovsc[g].append("-")
            print("-,", end =" ")
    print()
# Out:
# GT69-u , 0.30669425993853466 , 0.293199423225244 , 0.3507555296007007 , 0.2988766584485729 , 0.1859417954308466 , 0.18320443601342468 , 0.1720183486238532 , 0.12806353751235647 , 0.36736047607992145 ,

# %%
print("Final weighted overlap scores for each GT cluster:")
final_ovsc=dict()
for fam in ovsc.keys(): #ovsc.keys(): ['GT110-u']: 
    final_ovsc[fam]=list()
    print(fam, end=" ")
    for i,val in enumerate(ovsc[fam]):
        ovsc_norm=val-neg_ovsc[i]
        final_ovsc[fam].append(ovsc_norm)
        print(ovsc_norm,end=" ")
    print()
# Out:
# Final weighted overlap scores for each GT cluster:
# GT69-u -0.051547802001017995 0.03272951800817342 0.05399247077471747 -0.031975050164402274 -0.08642123249983685 -0.016726559448036082 -0.030823009437052767 -0.041028026880375934 0.08253515705003578

# %% [markdown]
# ### Plot distribution of desired cluster with test data

# %%
# Plot distribution of training vs test
scname='gtb1'
famname='GT109-u'
trainSC=train_data[scname]
# Plotting based in 
# testSC=test_data[scname]
# For plotting specific family within test results
test_here=test_data[scname]
testSC=test_here[test_here['fold'].str.contains(famname)]
(fig,ax)=Plot_Dist_SubClust_Extreme(trainSC,testSC,40,40)
ax.set_ylim(0,30)
ax.set_xlim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
figname="../output/"+scname+"_"+famname+"_dist.svg"
fig.savefig(figname,dpi=300)

# %% [markdown]
# ## Plot sec str map of sequence or families
